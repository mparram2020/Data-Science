# %%
import pandas as pd

# %%
df_data_historica = pd.read_csv('fifa_worldcup_historical_data.csv')
df_fixture = pd.read_csv('fifa_worldcup_fixture.csv')
df_fixture

# %%
df_fixture['home'].str.strip()
df_fixture['away'].str.strip()

# %%
#Eliminamos este partido porque fue dado a Suecia por 3-0
index_eliminar = df_data_historica[df_data_historica['home'].str.contains('Sweden') & df_data_historica['away'].str.contains('Austria')].index

# %%
df_data_historica.drop(index=index_eliminar, inplace=True)
df_data_historica
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-30081c8f4a5b> in <cell line: 1>()
# ----> 1 df_data_historica.drop(index=index_eliminar, inplace=True)
#       2 df_data_historica
#
# NameError: name 'df_data_historica' is not defined

# %%
#Separamos la columna score en score_home y score_away
df_data_historica['score'].str.split('–', expand=True)

# %%
df_data_historica
# Out:
#            home         score      away  year    home_goals
# 0       France            4–1    Mexico  1930           4–1
# 1    Argentina            1–0    France  1930           1–0
# 2        Chile            3–0    Mexico  1930           3–0
# 3        Chile            1–0    France  1930           1–0
# 4    Argentina            6–3    Mexico  1930           6–3
# ..          ...           ...       ...   ...           ...
# 860     Russia   2–2 (a.e.t.)   Croatia  2018  2–2 (a.e.t.)
# 861     France            1–0   Belgium  2018           1–0
# 862    Croatia   2–1 (a.e.t.)   England  2018  2–1 (a.e.t.)
# 863    Belgium            2–0   England  2018           2–0
# 864     France            4–2   Croatia  2018           4–2
#
# [864 rows x 5 columns]
